# %%
import pandas as pd

# %%
fert=pd.read_csv("../unsupervised-lemon-encounter-notes/week_01/data/gapminder_total_fertility.csv", index_col=0)
fert
# Out:
#                        1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# Total fertility rate
# Abkhazia                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# Algeria                6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
# ...                     ...   ...   ...   ...   ...   ...   ...   ...   ...
# Yugoslavia              NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Zambia                 6.71  6.71  6.71  6.71  6.71  6.71  6.71  6.71  6.71
# Zimbabwe               6.75  6.75  6.75  6.75  6.75  6.75  6.75  6.75  6.75
# Åland                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Åland                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# ...

# %%
life=pd.read_excel('../unsupervised-lemon-encounter-notes/week_01/data/gapminder_lifeexpectancy.xlsx', index_col=0)
life
# Out:
#                         1800   1801   1802   1803   1804   1805   1806   1807  \
# Life expectancy
# Abkhazia                 NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Afghanistan            28.21  28.20  28.19  28.18  28.17  28.16  28.15  28.14
# Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Albania                35.40  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# Algeria                28.82  28.82  28.82  28.82  28.82  28.82  28.82  28.82
# ...                      ...    ...    ...    ...    ...    ...    ...    ...
# Yugoslavia               NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Zambia                 32.60  32.60  32.60  32.60  32.60  32.60  32.60  32.60
# Zimbabwe               33.70  33.70  33.70  33.70  33.70  33.70  33.70  33.70
# Åland                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# South Sudan            26.67  26.67  26.67  26.67  26.67  26.67  26.67  26.67
#
# ...

# %%
life.columns
fert.columns
fert.columns=fert.columns.astype(int)

# %%
fert.index.name='country'
fert.index
# Out:
# Index(['Abkhazia', 'Afghanistan', 'Akrotiri and Dhekelia', 'Albania',
#        'Algeria', 'American Samoa', 'Andorra', 'Angola', 'Anguilla',
#        'Antigua and Barbuda',
#        ...
#        'Vietnam', 'Virgin Islands (U.S.)', 'North Yemen (former)',
#        'South Yemen (former)', 'Yemen', 'Yugoslavia', 'Zambia', 'Zimbabwe',
#        'Åland', 'Åland'],
#       dtype='object', name='country', length=260)

# %%
fert=fert.reset_index()

# %%
fert.head()
# Out:
#                  country  1800  1801  1802  1803  1804  1805  1806  1807  \
# 0               Abkhazia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1            Afghanistan  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# 2  Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3                Albania  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# 4                Algeria  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
#
#    1808  ...  2006  2007  2008  2009  2010  2011  2012  2013  2014  2015
# 0   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  7.00  ...  6.70  6.46  6.20  5.93  5.66  5.40  5.14  4.90  4.68  4.47
# 2   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  4.60  ...  1.85  1.80  1.76  1.74  1.74  1.75  1.76  1.77  1.78  1.78
# 4  6.99  ...  2.58  2.66  2.73  2.78  2.82  2.83  2.82  2.80  2.76  2.71
#
# [5 rows x 217 columns]

# %%
#convert to long format
fert = fert.melt(id_vars='country', var_name='year', value_name = 'fertility_rate')
fert
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b1a6123f8600> in <module>
#       1 #convert to long format
# ----> 2 fert = fert.melt(id_vars='country', var_name='year', value_name = 'fertility_rate')
#       3 fert
#
# NameError: name 'fert' is not defined

# %%
life.index.name = "country"
life
# Out:
#                         1800   1801   1802   1803   1804   1805   1806   1807  \
# country
# Abkhazia                 NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Afghanistan            28.21  28.20  28.19  28.18  28.17  28.16  28.15  28.14
# Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Albania                35.40  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# Algeria                28.82  28.82  28.82  28.82  28.82  28.82  28.82  28.82
# ...                      ...    ...    ...    ...    ...    ...    ...    ...
# Yugoslavia               NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Zambia                 32.60  32.60  32.60  32.60  32.60  32.60  32.60  32.60
# Zimbabwe               33.70  33.70  33.70  33.70  33.70  33.70  33.70  33.70
# Åland                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# South Sudan            26.67  26.67  26.67  26.67  26.67  26.67  26.67  26.67
#
# ...

# %%
life.index
# Out:
# Index(['Abkhazia', 'Afghanistan', 'Akrotiri and Dhekelia', 'Albania',
#        'Algeria', 'American Samoa', 'Andorra', 'Angola', 'Anguilla',
#        'Antigua and Barbuda',
#        ...
#        'Vietnam', 'Virgin Islands (U.S.)', 'North Yemen (former)',
#        'South Yemen (former)', 'Yemen', 'Yugoslavia', 'Zambia', 'Zimbabwe',
#        'Åland', 'South Sudan'],
#       dtype='object', name='country', length=260)

# %%
life = life.reset_index()
life.head(5)
# Out:
#                  country   1800   1801   1802   1803   1804   1805   1806  \
# 0               Abkhazia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1            Afghanistan  28.21  28.20  28.19  28.18  28.17  28.16  28.15
# 2  Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3                Albania  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# 4                Algeria  28.82  28.82  28.82  28.82  28.82  28.82  28.82
#
#     1807   1808  ...  2007  2008  2009  2010  2011  2012  2013  2014  2015  \
# 0    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  28.14  28.13  ...  52.4  52.8  53.3  53.6  54.0  54.4  54.8  54.9  53.8
# 2    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  35.40  35.40  ...  76.6  76.8  77.0  77.2  77.4  77.5  77.7  77.9  78.0
# 4  28.82  28.82  ...  75.3  75.5  75.7  76.0  76.1  76.2  76.3  76.3  76.4
#
#     2016
# 0    NaN
# 1  52.72
# 2    NaN
# 3  78.10
# 4  76.50
#
# ...

# %%
#convert to long format
life = life.melt(id_vars='country',var_name='year',value_name='life_expec')

# %%
life.head(5)
# Out:
#                  country  year  life_expec
# 0               Abkhazia  1800         NaN
# 1            Afghanistan  1800       28.21
# 2  Akrotiri and Dhekelia  1800         NaN
# 3                Albania  1800       35.40
# 4                Algeria  1800       28.82

# %%
popu=pd.read_excel("../unsupervised-lemon-encounter-notes/week_01/data/gapminder_population.xlsx",index_col=0)
popu.index.name="country"
popu.head(3)
popu = popu.reset_index()
popu
# Out:
#                                           country       1800       1810  \
# 0                                        Abkhazia        NaN        NaN
# 1                                     Afghanistan  3280000.0  3280000.0
# 2                           Akrotiri and Dhekelia        NaN        NaN
# 3                                         Albania   410445.0   423591.0
# 4                                         Algeria  2503218.0  2595056.0
# ..                                            ...        ...        ...
# 270                             Northern Marianas        NaN        NaN
# 271  South Georgia and the South Sandwich Islands        NaN        NaN
# 272                     US Minor Outlying Islands        NaN        NaN
# 273                                Virgin Islands        NaN        NaN
# 274                                     West Bank        NaN        NaN
#
#           1820       1830       1840       1850       1860       1870  \
# ...

# %%
popu=popu.melt(id_vars='country', var_name = 'year', value_name= 'population')
# the column with name of year has problem
#popu=popu.melt(id_vars='country')

popu
# Out:
#                                             country         year  population
# 0                                          Abkhazia         1800         NaN
# 1                                       Afghanistan         1800   3280000.0
# 2                             Akrotiri and Dhekelia         1800         NaN
# 3                                           Albania         1800    410445.0
# 4                                           Algeria         1800   2503218.0
# ...                                             ...          ...         ...
# 25020                             Northern Marianas  Unnamed: 91         NaN
# 25021  South Georgia and the South Sandwich Islands  Unnamed: 91         NaN
# 25022                     US Minor Outlying Islands  Unnamed: 91         NaN
# 25023                                Virgin Islands  Unnamed: 91         NaN
# 25024                                     West Bank  Unnamed: 91         NaN
#
# [25025 rows x 3 columns]

# %%
#popu=popu.melt(id_vars='country',var_name = 'year', value_name='papulation')
#popu=popu.rename(columns={'variable':'year','value':'population'})
#popu

# %%
df=fert.merge(life)
df
# Out:
#                      country  year  fertility_rate  life_expec
# 0                   Abkhazia  1800             NaN         NaN
# 1                Afghanistan  1800            7.00       28.21
# 2      Akrotiri and Dhekelia  1800             NaN         NaN
# 3                    Albania  1800            4.60       35.40
# 4                    Algeria  1800            6.99       28.82
# ...                      ...   ...             ...         ...
# 56155             Yugoslavia  2015             NaN         NaN
# 56156                 Zambia  2015            5.59       56.70
# 56157               Zimbabwe  2015            3.35       59.30
# 56158                  Åland  2015             NaN         NaN
# 56159                  Åland  2015             NaN         NaN
#
# [56160 rows x 4 columns]

# %%
df=df.merge(popu)
df
# Out:
#                      country  year  fertility_rate  life_expec  population
# 0                   Abkhazia  1800             NaN         NaN         NaN
# 1                Afghanistan  1800            7.00       28.21   3280000.0
# 2      Akrotiri and Dhekelia  1800             NaN         NaN         NaN
# 3                    Albania  1800            4.60       35.40    410445.0
# 4                    Algeria  1800            6.99       28.82   2503218.0
# ...                      ...   ...             ...         ...         ...
# 20974             Yugoslavia  2015             NaN         NaN         NaN
# 20975                 Zambia  2015            5.59       56.70  16211767.0
# 20976               Zimbabwe  2015            3.35       59.30  15602751.0
# 20977                  Åland  2015             NaN         NaN         NaN
# 20978                  Åland  2015             NaN         NaN         NaN
#
# [20979 rows x 5 columns]

# %%
df.isna()
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))
sns.heatmap(df.isna(), cbar=False)
df.dropna(inplace=True)

# %%
sns.heatmap(df.isna(), cbar=False)
# Out:
# <AxesSubplot:>

# %%
df_y_cl=df[df['year']>1959]

df_y_cl
# Out:
#                      country  year  fertility_rate  life_expec  population
# 6476             Afghanistan  1960            7.67       31.94   8994793.0
# 6478                 Albania  1960            6.19       62.87   1636054.0
# 6479                 Algeria  1960            7.65       47.50  11124892.0
# 6482                  Angola  1960            7.32       35.98   5270844.0
# 6484     Antigua and Barbuda  1960            4.43       62.97     54681.0
# ...                      ...   ...             ...         ...         ...
# 20969                Vietnam  2015            1.70       75.40  93447601.0
# 20970  Virgin Islands (U.S.)  2015            2.45       80.60    106291.0
# 20973                  Yemen  2015            3.83       66.00  26832215.0
# 20975                 Zambia  2015            5.59       56.70  16211767.0
# 20976               Zimbabwe  2015            3.35       59.30  15602751.0
#
# [11250 rows x 5 columns]

# %%
df['country'].isin(['France', 'Germany', 'Sweden'])
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 20974    False
# 20975    False
# 20976    False
# 20977    False
# 20978    False
# Name: country, Length: 20979, dtype: bool

# %%
df_subset = df.loc[df['country'].isin(['France', 'Germany', 'Sweden'])]
df_subset
# Out:
#        country  year  fertility_rate  life_expec  population
# 76      France  1800            4.41       33.97  29355111.0
# 82     Germany  1800            5.40       38.37  22886919.0
# 217     Sweden  1800            4.07       32.16   2354189.0
# 335     France  1810            3.90       37.40  30293172.0
# 341    Germany  1810            5.35       38.37  23882461.0
# ...        ...   ...             ...         ...         ...
# 20543  Germany  2014            1.43       80.70  80646262.0
# 20678   Sweden  2014            1.93       82.10   9703247.0
# 20796   France  2015            1.98       81.80  64395345.0
# 20802  Germany  2015            1.44       80.80  80688545.0
# 20937   Sweden  2015            1.93       82.10   9779426.0
#
# [243 rows x 5 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.lineplot(x='year',y='life_expec',hue='country',data=df_subset)
# Out:
# <AxesSubplot:xlabel='year', ylabel='life_expec'>

# %%
#sns.scatterplot(x='year',y='life_expec',hue='country',data=df_subset, alpha=0.6)

# %%
df_subset_y=df_subset[df['year']>1959]
df_subset_y
# Out:
# <ipython-input-24-5f26dfdf0232>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_subset_y=df_subset[df['year']>1959]
#        country  year  fertility_rate  life_expec  population
# 6551    France  1960            2.77       70.49  45865699.0
# 6557   Germany  1960            2.41       69.26  73179665.0
# 6692    Sweden  1960            2.20       73.01   7479602.0
# 6810    France  1961            2.80       71.07  46471083.0
# 6816   Germany  1961            2.44       69.85  73686490.0
# ...        ...   ...             ...         ...         ...
# 20543  Germany  2014            1.43       80.70  80646262.0
# 20678   Sweden  2014            1.93       82.10   9703247.0
# 20796   France  2015            1.98       81.80  64395345.0
# 20802  Germany  2015            1.44       80.80  80688545.0
# 20937   Sweden  2015            1.93       82.10   9779426.0
#
# [168 rows x 5 columns]

# %%
df_y_cl=df[df['year']>1959]
#df_y_cl=df_y.dropna()
df_y_cl
df_y_cl_1960=df_y_cl[df_y_cl['year']==1960]
df_y_cl_1960
fig,ax=plt.subplots(figsize=(7,7))
ax= sns.scatterplot(data=df_y_cl_1960, y='fertility_rate',x='life_expec')

#plt.savefig('df_y_cl_1960.png')
# plt.show()

# %%
df_y_cl_2000
# Out:
#                      country  year  fertility_rate  life_expec  population
# 16836            Afghanistan  2000            7.73       50.10  19701940.0
# 16838                Albania  2000            2.38       74.70   3121965.0
# 16839                Algeria  2000            2.51       73.30  31183658.0
# 16842                 Angola  2000            6.84       52.30  15058638.0
# 16844    Antigua and Barbuda  2000            2.32       73.80     77648.0
# ...                      ...   ...             ...         ...         ...
# 17084                Vietnam  2000            1.98       72.00  80285563.0
# 17085  Virgin Islands (U.S.)  2000            2.10       77.57    108511.0
# 17088                  Yemen  2000            6.36       62.40  17795219.0
# 17090                 Zambia  2000            6.07       44.80  10585220.0
# 17091               Zimbabwe  2000            4.07       47.90  12499981.0
#
# [201 rows x 5 columns]

# %%
df_y_cl_2000=df[df['year']==2000]
mini=df_y_cl_2000['population'].min()
maxi=df_y_cl_2000['population'].max()
fig,ax=plt.subplots(figsize=(14,14))
ax= sns.scatterplot(data=df_y_cl_2000, y='fertility_rate',x='life_expec',size='population',sizes=(mini*0.000001,maxi*0.000004))
#plt.title("Fertility_rate and life_expection in year {}".format(i))
#plt.savefig('df_y_cl_{}.png'.format(i))
plt.show()

# %%
#(df_y_cl['population']/1000000).describe()

df_y_cl.loc[df_y_cl['population'] > 40000000,'country_size'] = 'L'
df_y_cl.loc[(df_y_cl['population']> 1000000)&(df_y_cl['population']<40000000),'country_size']='M'  
    
#elif df_y_cl['population'] > 10000000 & df_y_cl['population'] < 40000000:
#     df_y_cl['country_size']='M'
# df_y_cl['country_size']='S'



df_y_cl.loc[df_y_cl['population'] < 10000000,'country_size'] = 'S'
# Out:
# /home/baodong/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /home/baodong/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /home/baodong/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# ...

# %%
df_y_cl['country_size']
# Out:
# 6476     S
# 6478     S
# 6479     M
# 6482     S
# 6484     S
#         ..
# 20969    L
# 20970    S
# 20973    M
# 20975    M
# 20976    M
# Name: country_size, Length: 11250, dtype: object

# %%
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df_y_cl['population'].max()
# Out:
# 1376048943.0

# %%
fig,ax=plt.subplots(figsize=(14,14))
df_y_cl_1960=df_y_cl[df_y_cl['year']==1960]
ax= sns.scatterplot(data=df_y_cl_1960, y='fertility_rate',x='life_expec',hue='country_size',
                    size='country_size',size_order=['L','M','S'],sizes=(100,300))

# %%
continent=pd.read_csv('~/spiced_projects/unsupervised-lemon-student-code/continents.csv', sep=';')
continent
# Out:
#          continent    country
# 0           Africa    Algeria
# 1           Africa     Angola
# 2           Africa      Benin
# 3           Africa   Botswana
# 4           Africa    Burkina
# ..             ...        ...
# 189  South America   Paraguay
# 190  South America       Peru
# 191  South America   Suriname
# 192  South America    Uruguay
# 193  South America  Venezuela
#
# [194 rows x 2 columns]

# %%
df_y_cl_con=pd.merge(left=df_y_cl, right=continent, how='left', on='country')
df_y_cl_con
# Out:
#                      country  year  fertility_rate  life_expec  population  \
# 0                Afghanistan  1960            7.67       31.94   8994793.0
# 1                    Albania  1960            6.19       62.87   1636054.0
# 2                    Algeria  1960            7.65       47.50  11124892.0
# 3                     Angola  1960            7.32       35.98   5270844.0
# 4        Antigua and Barbuda  1960            4.43       62.97     54681.0
# ...                      ...   ...             ...         ...         ...
# 11245                Vietnam  2015            1.70       75.40  93447601.0
# 11246  Virgin Islands (U.S.)  2015            2.45       80.60    106291.0
# 11247                  Yemen  2015            3.83       66.00  26832215.0
# 11248                 Zambia  2015            5.59       56.70  16211767.0
# 11249               Zimbabwe  2015            3.35       59.30  15602751.0
#
#       country_size      continent
# ...

# %%
df_y_cl_con_1990= df_y_cl_con[df_y_cl_con['year']==1990]
df_y_cl_con_1990
#fg,ax = plt.subplots(figsize=(14,14)) #doesn't work
#sns.set(rc={'figure.figsize':(30,30)}) # change default figure size #doesn't work
#plt.rcParams['figure.figsize']=20,20 #doesn't work
g=sns.relplot(x= 'life_expec' , y='fertility_rate', hue='continent',size='country_size',size_order=('L','M','S'),data=df_y_cl_con_1990, kind='scatter',sizes=(200,600))
g.fig.set_size_inches(14,14) #does work !!! style='continent'

# %%
df_y_cl_con_1990
# Out:
#                     country  year  fertility_rate  life_expec  population  \
# 6030            Afghanistan  1990            7.69       49.50  12067570.0
# 6031                Albania  1990            2.97       73.30   3281453.0
# 6032                Algeria  1990            4.76       70.20  25912364.0
# 6033                 Angola  1990            7.17       48.60  11127870.0
# 6034    Antigua and Barbuda  1990            2.06       73.50     61906.0
# ...                     ...   ...             ...         ...         ...
# 6226                Vietnam  1990            3.56       69.30  68209604.0
# 6227  Virgin Islands (U.S.)  1990            2.95       74.73    103253.0
# 6228                  Yemen  1990            8.67       58.50  11961099.0
# 6229                 Zambia  1990            6.47       51.90   8143142.0
# 6230               Zimbabwe  1990            5.18       63.00  10484771.0
#
#      country_size      continent
# 6030            M           Asia
# ...

# %%
df_y_cl_con_1990['population'].loc(df_y_cl_con_1990['continent'] == "Asia").plot(kind='hist')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-2608c1b30453> in <module>
# ----> 1 df_y_cl_con_1990['population'].loc(df_y_cl_con_1990['continent'] == "Asia").plot(kind='hist')
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __call__(self, axis)
#     605
#     606         if axis is not None:
# --> 607             axis = self.obj._get_axis_number(axis)
#     608         new_self.axis = axis
#     609         return new_self
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     458     def _get_axis_number(cls, axis: Axis) -> int:
#     459         try:
# --> 460             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     461         except KeyError:
#     462             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# ...

# %%
# whether the life_expections in different continent in 1990 are the same?
sns.catplot(data=df_y_cl_con_1990,x='continent',y='life_expec',kind='box')

# %%
#sns.pairplot(data=df_y_cl_con_1990, hue='continent')

# %%
ax=plt.subplots(figsize=(8,8))
#gm_pearsoncorr=df_y_cl_con_1990['fertility_rate','life_expec','population'].corr(method='pearson')  why doesn't work.
gm_pearsoncorr=df_y_cl_con_1990.corr(method='pearson')
sns.heatmap(gm_pearsoncorr,xticklabels=gm_pearsoncorr.columns, yticklabels=gm_pearsoncorr.columns, color='green', annot=True).set_title('Pearson correlation between lolumns')
# Out:
# Text(0.5, 1.0, 'Pearson correlation between lolumns')

# %%
groups = df_y_cl_con_1990.groupby('continent')

# %%
import numpy as np
import pandas as pd

#pd.set_option('display.height',1000)
# pd.set_option('display.max_rows',500)
# pd.set_option('display.max_columns',500)
pd.set_option('display.width',1000)

#for group in groups:
 #   print(group)

# %%
df_y_cl_con_groups=df_y_cl_con_1990.groupby(['country_size','continent'])

# %%
df_y_cl_con_groups.aggregate({'life_expec':'mean','fertility_rate':'std'})
# Out:
#                                     life_expec  fertility_rate
# country_size continent
# L            Africa                  54.833333        1.503729
#              Asia                    66.354545        1.305933
#              Europe                  75.060000        0.267152
#              North America           73.450000        0.926310
#              South America           67.900000             NaN
# M            Africa                  58.615385        1.071420
#              Asia                    65.460000        1.998309
#              Australia and Oceania   77.000000             NaN
#              Europe                  72.950000        0.240799
#              North America           76.050000        0.021213
#              South America           71.583333        0.473821
# S            Africa                  56.996970        1.274953
#              Asia                    69.306250        1.450071
#              Australia and Oceania   64.362500        1.077808
# ...

# %%
df_y_con_n= df_y_cl_con.drop('country_size',axis=1,inplace=True)
df_y_cl_con.columns
# Out:
# Index(['country', 'year', 'fertility_rate', 'life_expec', 'population', 'continent'], dtype='object')

# %%
# for i in range(1960,2016):
#     df_y_n=df_y_cl[df_y_cl['year']== i]
#     mini=df_y_n['population'].min()
#     maxi=df_y_n['population'].max()
#     fig,ax=plt.subplots(figsize=(7,7))
#     ax= sns.scatterplot(data=df_y_n, y='fertility_rate',x='life_expec',size='population',sizes=(mini*0.00001,maxi*0.00004))
#     plt.title("Fertility_rate and life_expection in year {}".format(i))
#     plt.savefig('df_y_cl_{}.png'.format(i))
#     plt.show()

#pip install imageio
#import imageio

#images = []

#for i in range(2000, 2015):
 #   filename = 'df_y_cl_{}.png'.format(i)
  #  images.append(imageio.imread(filename))

#imageio.mimsave('output.gif', images, fps=20)
