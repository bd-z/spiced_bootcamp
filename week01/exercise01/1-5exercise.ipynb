# %%
import pandas

spices = ['One-Hot Chili Peppers',
          'Bayesian Basil',
          'Tensor Thyme'
          'Linear Lavender',
          'Artificial Neural Nutmeg',
          'Polynomial Peppermint',
          'Sigmoid Saffron'
          ]
participants = [2, 6, 9, 9, 9, 8]

df = pd.DataFrame({'name': spices},
                   {'participants': participants
                   })

print(sort_values(by='participants', ascending=False))

print("\ntotal participants:", df.sum(['participants']))

# %%
print(df.sort_values(by='participants', ascending=False))
# Out:
#                           name  participants
# 2  Tensor ThymeLinear Lavender             9
# 3     Artificial Neural Nutmeg             9
# 4        Polynomial Peppermint             9
# 5              Sigmoid Saffron             8
# 1               Bayesian Basil             6
# 0        One-Hot Chili Peppers             2

# %%
print("\ntotal participants:", df['participants'].sum())
# Out:
# total participants: 43

# %%
import pandas as pd
spices = ['One-Hot Chili Peppers',
          'Bayesian Basil',
          'Tensor Thyme'
          'Linear Lavender',
          'Artificial Neural Nutmeg',
          'Polynomial Peppermint',
          'Sigmoid Saffron'
          ]

# %%
participants = [2, 6, 9, 9, 9, 8]

# %%
df = pd.DataFrame({'name': spices,'participants': participants})
df
# Out:
#                           name  participants
# 0        One-Hot Chili Peppers             2
# 1               Bayesian Basil             6
# 2  Tensor ThymeLinear Lavender             9
# 3     Artificial Neural Nutmeg             9
# 4        Polynomial Peppermint             9
# 5              Sigmoid Saffron             8

# %%
    Examine the file data/continents.csv:

    import pandas as pd

    # 1. read the file into a DataFrame
    df_con=pd.read_csv('continents.csv',sep=";")

    # 2. display the number of rows and columns
    df_con.shape

    # 3. display the first 5 countries in the alphabet
    df_con.head(5)

    # 4. which continent has the most countries?
    
    grouped = df_con.groupby('continent')
    grouped.size()

    # 5. find out on which continent Cyprus is
      import numpy as np
mask = df_con['country'] == 'Cyprus'
pos = np.flatnonzero(mask)  # 返回的是array([0, 2, 4, 6, 7])
df_con.iloc[pos]

    
    # 6. define a DataFrame with all African countries
    africa = grouped.get_group('Africa')

    # 7. define a DataFrame with countries 80 through 100
    subset = df_con.ilos[80:100]

    # 8. select every second country
a=[]
for i in range(2,len(df_con),2):
    a.append(i)
df_con['country'].iloc[a]

# %%
df_con=pd.read_csv('continents.csv',sep=";")

# %%
subset = df_con.iloc[80:100]

# %%
subset
# Out:
#    continent               country
# 80      Asia                 Nepal
# 81      Asia                  Oman
# 82      Asia              Pakistan
# 83      Asia           Philippines
# 84      Asia                 Qatar
# 85      Asia    Russian Federation
# 86      Asia          Saudi Arabia
# 87      Asia             Singapore
# 88      Asia             Sri Lanka
# 89      Asia                 Syria
# 90      Asia            Tajikistan
# 91      Asia              Thailand
# 92      Asia                Turkey
# 93      Asia          Turkmenistan
# 94      Asia  United Arab Emirates
# 95      Asia            Uzbekistan
# 96      Asia               Vietnam
# 97      Asia                 Yemen
# 98    Europe               Albania
# 99    Europe               Andorra

# %%
import os
os.getcwd()
os.listdir()
# Out:
# ['continents.csv',
#  'pengui_clean.csv',
#  'population.csv',
#  'titanic_select_row_column.ipynb',
#  '.gitignore',
#  'mean_calculation.ipynb',
#  '.ipynb_checkpoints',
#  'penguins_simple.csv',
#  'introduction_to_pandas.ipynb',
#  '1_6DescriptiveStatistics_exercise.ipynb',
#  'hello.py',
#  '.git',
#  '未命名.ipynb']

# %%
df_con.shape
# Out:
# (194, 2)

# %%
df_con[df_con['continent'].isin(['Cyprus'])]
# Out:
# Empty DataFrame
# Columns: [continent, country]
# Index: []

# %%
df_con['continent'].isin(['China'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 189    False
# 190    False
# 191    False
# 192    False
# 193    False
# Name: continent, Length: 194, dtype: bool

# %%
 africa = grouped.get_group('Africa')

# %%
africa
# Out:
#    continent                        country
# 0     Africa                        Algeria
# 1     Africa                         Angola
# 2     Africa                          Benin
# 3     Africa                       Botswana
# 4     Africa                        Burkina
# 5     Africa                        Burundi
# 6     Africa                       Cameroon
# 7     Africa                     Cape Verde
# 8     Africa       Central African Republic
# 9     Africa                           Chad
# 10    Africa                        Comoros
# 11    Africa                          Congo
# 12    Africa  Congo, Democratic Republic of
# 13    Africa                       Djibouti
# 14    Africa                          Egypt
# 15    Africa              Equatorial Guinea
# 16    Africa                        Eritrea
# 17    Africa                       Ethiopia
# 18    Africa                          Gabon
# 19    Africa                         Gambia
# ...

# %%
import numpy as np
mask = df_con['country'] == 'Cyprus'
pos = np.flatnonzero(mask)  # 返回的是array([0, 2, 4, 6, 7])
df_con.iloc[pos]
# Out:
#     continent country
# 108    Europe  Cyprus

# %%
#print(mask)
#print(pos)
mask[[107,108]]
# Out:
# 107    False
# 108     True
# Name: country, dtype: bool

# %%
df_con['continent'].unique()
# Out:
# array(['Africa', 'Asia', 'Europe', 'North America',
#        'Australia and Oceania', 'South America'], dtype=object)

# %%
grouped = df_con.groupby('continent')

# %%
# grouped.get_group('North America')

# %% [raw]
# grouped.agg(['count'])

# %%
grouped.size()
# Out:
# continent
# Africa                   54
# Asia                     44
# Australia and Oceania    14
# Europe                   47
# North America            23
# South America            12
# dtype: int64

# %%
# group = list(group)

# %%
grouped.max()
# Out:
#                              country
# continent
# Africa                      Zimbabwe
# Asia                           Yemen
# Australia and Oceania        Vanuatu
# Europe                  Vatican City
# North America          United States
# South America              Venezuela

# %%
df_con.head()
# Out:
#   continent   country
# 0    Africa   Algeria
# 1    Africa    Angola
# 2    Africa     Benin
# 3    Africa  Botswana
# 4    Africa   Burkina

# %%
a=[]
for i in range(2,len(df_con),2):
    a.append(i)
df_con['country'].iloc[a]
# Out:
# 2                         Benin
# 4                       Burkina
# 6                      Cameroon
# 8      Central African Republic
# 10                      Comoros
#                  ...
# 184                      Brazil
# 186                    Colombia
# 188                      Guyana
# 190                        Peru
# 192                     Uruguay
# Name: country, Length: 96, dtype: object
